# %%
import pandas as pd

# %%
# Import complete accident information dataset
file_1 = "Resources/Accident_Information.csv"
accident_df = pd.read_csv(file_1)

accident_df.head()
# Out:
# C:\Users\gcwhi\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   Accident_Index 1st_Road_Class  1st_Road_Number 2nd_Road_Class  \
# 0  200501BS00001              A           3218.0            NaN
# 1  200501BS00002              B            450.0              C
# 2  200501BS00003              C              0.0            NaN
# 3  200501BS00004              A           3220.0            NaN
# 4  200501BS00005   Unclassified              0.0            NaN
#
#    2nd_Road_Number Accident_Severity Carriageway_Hazards        Date  \
# 0              0.0           Serious                None  2005-01-04
# 1              0.0            Slight                None  2005-01-05
# 2              0.0            Slight                None  2005-01-06
# ...

# %%
# select required columns
columns = ['Accident_Index', '1st_Road_Class','Accident_Severity','Carriageway_Hazards','Year','Date','Day_of_Week','Did_Police_Officer_Attend_Scene_of_Accident','Junction_Control','Junction_Detail','Junction_Detail','Latitude','Light_Conditions','Local_Authority_(District)','Local_Authority_(Highway)','Longitude','Number_of_Casualties','Number_of_Vehicles','Road_Surface_Conditions','Road_Type','Special_Conditions_at_Site','Speed_limit','Time','Urban_or_Rural_Area','Weather_Conditions']
           
acc_df1 = pd.DataFrame(accident_df, columns=columns)
acc_df1
# Out:
#         Accident_Index 1st_Road_Class Accident_Severity  \
# 0        200501BS00001              A           Serious
# 1        200501BS00002              B            Slight
# 2        200501BS00003              C            Slight
# 3        200501BS00004              A            Slight
# 4        200501BS00005   Unclassified            Slight
# ...                ...            ...               ...
# 2047251  2017984121017           A(M)            Slight
# 2047252  2017984121217              C            Slight
# 2047253  2017984121717           A(M)            Slight
# 2047254  2017984122317              A            Slight
# 2047255  2017984122617              B           Serious
#
#                              Carriageway_Hazards  Year        Date  \
# 0                                           None  2005  2005-01-04
# 1                                           None  2005  2005-01-05
# 2                                           None  2005  2005-01-06
# ...

# %%
#review data types
acc_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2047256 entries, 0 to 2047255
# Data columns (total 25 columns):
#  #   Column                                       Dtype
# ---  ------                                       -----
#  0   Accident_Index                               object
#  1   1st_Road_Class                               object
#  2   Accident_Severity                            object
#  3   Carriageway_Hazards                          object
#  4   Year                                         int64
#  5   Date                                         object
#  6   Day_of_Week                                  object
#  7   Did_Police_Officer_Attend_Scene_of_Accident  float64
#  8   Junction_Control                             object
#  9   Junction_Detail                              object
#  10  Junction_Detail                              object
#  11  Latitude                                     float64
# ...

# %%
acc_df1.count()
# Out:
# Accident_Index                                 2047256
# 1st_Road_Class                                 2047256
# Accident_Severity                              2047256
# Carriageway_Hazards                            2047256
# Year                                           2047256
# Date                                           2047256
# Day_of_Week                                    2047256
# Did_Police_Officer_Attend_Scene_of_Accident    2046978
# Junction_Control                               2047256
# Junction_Detail                                2047256
# Junction_Detail                                2047256
# Latitude                                       2047082
# Light_Conditions                               2047256
# Local_Authority_(District)                     2047256
# Local_Authority_(Highway)                      2047256
# Longitude                                      2047081
# Number_of_Casualties                           2047256
# ...

# %%
#remove data with misssing values
acc_df2=acc_df1.dropna(how='any')
acc_df2
# Out:
#         Accident_Index 1st_Road_Class Accident_Severity  \
# 0        200501BS00001              A           Serious
# 1        200501BS00002              B            Slight
# 2        200501BS00003              C            Slight
# 3        200501BS00004              A            Slight
# 4        200501BS00005   Unclassified            Slight
# ...                ...            ...               ...
# 2047251  2017984121017           A(M)            Slight
# 2047252  2017984121217              C            Slight
# 2047253  2017984121717           A(M)            Slight
# 2047254  2017984122317              A            Slight
# 2047255  2017984122617              B           Serious
#
#                              Carriageway_Hazards  Year        Date  \
# 0                                           None  2005  2005-01-04
# 1                                           None  2005  2005-01-05
# 2                                           None  2005  2005-01-06
# ...

# %%
#check to see if dropna worked
acc_df2.count()
# Out:
# Accident_Index                                 2046611
# 1st_Road_Class                                 2046611
# Accident_Severity                              2046611
# Carriageway_Hazards                            2046611
# Year                                           2046611
# Date                                           2046611
# Day_of_Week                                    2046611
# Did_Police_Officer_Attend_Scene_of_Accident    2046611
# Junction_Control                               2046611
# Junction_Detail                                2046611
# Junction_Detail                                2046611
# Latitude                                       2046611
# Light_Conditions                               2046611
# Local_Authority_(District)                     2046611
# Local_Authority_(Highway)                      2046611
# Longitude                                      2046611
# Number_of_Casualties                           2046611
# ...

# %%
#repeat the process with the second dataset
file_2 = "Resources/Vehicle_Information.csv"
vehicle_df = pd.read_csv(file_2)

vehicle_df.head()
# Out:
#   Accident_Index Age_Band_of_Driver  Age_of_Vehicle  \
# 0  200401BS00001            26 - 35             3.0
# 1  200401BS00002            26 - 35             NaN
# 2  200401BS00003            26 - 35             4.0
# 3  200401BS00003            66 - 75             NaN
# 4  200401BS00004            26 - 35             1.0
#
#           Driver_Home_Area_Type  Driver_IMD_Decile  Engine_Capacity_.CC.  \
# 0                    Urban area                4.0                1588.0
# 1                    Urban area                3.0                   NaN
# 2  Data missing or out of range                NaN                 998.0
# 3  Data missing or out of range                NaN                   NaN
# 4                    Urban area                4.0                 124.0
#
#   Hit_Object_in_Carriageway Hit_Object_off_Carriageway  \
# 0                      None                       None
# 1                      None                       None
# ...

# %%
#repeat the process with the second dataset
columns1 = ['Accident_Index', 'Age_Band_of_Driver','Age_of_Vehicle','Driver_Home_Area_Type','Engine_Capacity_.CC.','Hit_Object_in_Carriageway','Hit_Object_off_Carriageway','Journey_Purpose_of_Driver','Junction_Location','make','model','Propulsion_Code','Sex_of_Driver','Towing_and_Articulation','Vehicle_Manoeuvre','Vehicle_Type','Was_Vehicle_Left_Hand_Drive','X1st_Point_of_Impact']
           
veh_df1 = pd.DataFrame(vehicle_df, columns=columns1)
veh_df1
# Out:
#         Accident_Index Age_Band_of_Driver  Age_of_Vehicle  \
# 0        200401BS00001            26 - 35             3.0
# 1        200401BS00002            26 - 35             NaN
# 2        200401BS00003            26 - 35             4.0
# 3        200401BS00003            66 - 75             NaN
# 4        200401BS00004            26 - 35             1.0
# ...                ...                ...             ...
# 2177200  2016984131116            21 - 25            14.0
# 2177201  2016984131116            56 - 65             NaN
# 2177202  2016984131216            56 - 65             NaN
# 2177203  2016984131316            16 - 20            13.0
# 2177204  2016984133416            46 - 55             5.0
#
#                 Driver_Home_Area_Type  Engine_Capacity_.CC.  \
# 0                          Urban area                1588.0
# 1                          Urban area                   NaN
# 2        Data missing or out of range                 998.0
# ...

# %%
#repeat the process with the second dataset
veh_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2177205 entries, 0 to 2177204
# Data columns (total 18 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   Accident_Index               object
#  1   Age_Band_of_Driver           object
#  2   Age_of_Vehicle               float64
#  3   Driver_Home_Area_Type        object
#  4   Engine_Capacity_.CC.         float64
#  5   Hit_Object_in_Carriageway    object
#  6   Hit_Object_off_Carriageway   object
#  7   Journey_Purpose_of_Driver    object
#  8   Junction_Location            object
#  9   make                         object
#  10  model                        object
#  11  Propulsion_Code              object
#  12  Sex_of_Driver                object
#  13  Towing_and_Articulation      object
#  14  Vehicle_Manoeuvre            object
#  15  Vehicle_Type                 object
#  16  Was_Vehicle_Left_Hand_Drive  object
#  17  X1st_Point_of_Impact         object
# ...

# %%
#repeat the process with the second dataset
veh_df1.count()
# Out:
# Accident_Index                 2177205
# Age_Band_of_Driver             2177205
# Age_of_Vehicle                 1819056
# Driver_Home_Area_Type          2177205
# Engine_Capacity_.CC.           1911344
# Hit_Object_in_Carriageway      2177205
# Hit_Object_off_Carriageway     2177205
# Journey_Purpose_of_Driver      2177205
# Junction_Location              2177205
# make                           2066360
# model                          1851874
# Propulsion_Code                1931362
# Sex_of_Driver                  2177205
# Towing_and_Articulation        2177205
# Vehicle_Manoeuvre              2177205
# Vehicle_Type                   2177205
# Was_Vehicle_Left_Hand_Drive    2177205
# X1st_Point_of_Impact           2177205
# dtype: int64

# %%
#repeat the process with the second dataset
veh_df2=veh_df1.dropna(how='any')
veh_df2
# Out:
#         Accident_Index            Age_Band_of_Driver  Age_of_Vehicle  \
# 0        200401BS00001                       26 - 35             3.0
# 2        200401BS00003                       26 - 35             4.0
# 4        200401BS00004                       26 - 35             1.0
# 9        200401BS00013                       26 - 35             4.0
# 10       200401BS00013                       21 - 25             3.0
# ...                ...                           ...             ...
# 2177198  2016984130916                       46 - 55             8.0
# 2177199  2016984130916  Data missing or out of range            11.0
# 2177200  2016984131116                       21 - 25            14.0
# 2177203  2016984131316                       16 - 20            13.0
# 2177204  2016984133416                       46 - 55             5.0
#
#                 Driver_Home_Area_Type  Engine_Capacity_.CC.  \
# 0                          Urban area                1588.0
# ...

# %%
#repeat the process with the second dataset
veh_df2.count()
# Out:
# Accident_Index                 1634518
# Age_Band_of_Driver             1634518
# Age_of_Vehicle                 1634518
# Driver_Home_Area_Type          1634518
# Engine_Capacity_.CC.           1634518
# Hit_Object_in_Carriageway      1634518
# Hit_Object_off_Carriageway     1634518
# Journey_Purpose_of_Driver      1634518
# Junction_Location              1634518
# make                           1634518
# model                          1634518
# Propulsion_Code                1634518
# Sex_of_Driver                  1634518
# Towing_and_Articulation        1634518
# Vehicle_Manoeuvre              1634518
# Vehicle_Type                   1634518
# Was_Vehicle_Left_Hand_Drive    1634518
# X1st_Point_of_Impact           1634518
# dtype: int64

# %%
#review data types
veh_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1634518 entries, 0 to 2177204
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   Accident_Index               1634518 non-null  object
#  1   Age_Band_of_Driver           1634518 non-null  object
#  2   Age_of_Vehicle               1634518 non-null  float64
#  3   Driver_Home_Area_Type        1634518 non-null  object
#  4   Engine_Capacity_.CC.         1634518 non-null  float64
#  5   Hit_Object_in_Carriageway    1634518 non-null  object
#  6   Hit_Object_off_Carriageway   1634518 non-null  object
#  7   Journey_Purpose_of_Driver    1634518 non-null  object
#  8   Junction_Location            1634518 non-null  object
#  9   make                         1634518 non-null  object
#  10  model                        1634518 non-null  object
#  11  Propulsion_Code              1634518 non-null  object
# ...

# %%
#merge the datasets using an outer merge
df2_merge = acc_df2.merge(veh_df2, on="Accident_Index", how = 'outer')
df2_merge
# Out:
#         Accident_Index 1st_Road_Class Accident_Severity Carriageway_Hazards  \
# 0        200501BS00001              A           Serious                None
# 1        200501BS00002              B            Slight                None
# 2        200501BS00003              C            Slight                None
# 3        200501BS00004              A            Slight                None
# 4        200501BS00005   Unclassified            Slight                None
# ...                ...            ...               ...                 ...
# 2536714  2016961600599            NaN               NaN                 NaN
# 2536715  2016961600599            NaN               NaN                 NaN
# 2536716  2016961601188            NaN               NaN                 NaN
# 2536717  2016961601188            NaN               NaN                 NaN
# 2536718  2016961601508            NaN               NaN                 NaN
#
#            Year        Date Day_of_Week  \
# ...

# %%
#review the data types and columns
df2_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2536719 entries, 0 to 2536718
# Data columns (total 42 columns):
#  #   Column                                       Dtype
# ---  ------                                       -----
#  0   Accident_Index                               object
#  1   1st_Road_Class                               object
#  2   Accident_Severity                            object
#  3   Carriageway_Hazards                          object
#  4   Year                                         float64
#  5   Date                                         object
#  6   Day_of_Week                                  object
#  7   Did_Police_Officer_Attend_Scene_of_Accident  float64
#  8   Junction_Control                             object
#  9   Junction_Detail                              object
#  10  Junction_Detail                              object
#  11  Latitude                                     float64
# ...

# %%
#remove any rows with missing or values
df2_drop=df2_merge.dropna(how='any')
df2_drop
# Out:
#         Accident_Index 1st_Road_Class Accident_Severity Carriageway_Hazards  \
# 3        200501BS00004              A            Slight                None
# 5        200501BS00006   Unclassified            Slight                None
# 6        200501BS00006   Unclassified            Slight                None
# 7        200501BS00007              C            Slight                None
# 8        200501BS00009              A            Slight                None
# ...                ...            ...               ...                 ...
# 2328485  2016984130916              B            Slight                None
# 2328486  2016984130916              B            Slight                None
# 2328487  2016984131116              B            Slight                None
# 2328489  2016984131316              B            Slight                None
# 2328490  2016984133416           A(M)            Slight                None
#
#            Year        Date Day_of_Week  \
# ...

# %%
#review types
df2_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1556240 entries, 3 to 2328490
# Data columns (total 42 columns):
#  #   Column                                       Non-Null Count    Dtype
# ---  ------                                       --------------    -----
#  0   Accident_Index                               1556240 non-null  object
#  1   1st_Road_Class                               1556240 non-null  object
#  2   Accident_Severity                            1556240 non-null  object
#  3   Carriageway_Hazards                          1556240 non-null  object
#  4   Year                                         1556240 non-null  float64
#  5   Date                                         1556240 non-null  object
#  6   Day_of_Week                                  1556240 non-null  object
#  7   Did_Police_Officer_Attend_Scene_of_Accident  1556240 non-null  float64
#  8   Junction_Control                             1556240 non-null  object
# ...

# %%
# Export file as a CSV, without the Pandas index, but with the header
df2_drop.to_csv("Resources/df2.csv", index=False, header=True)
