# %%
import pandas as pd

# %%
# retrieve cleansed data from step 2
file_4 = "Resources/data_cleaned.csv"
final_df = pd.read_csv(file_4)

final_df.head()
# Out:
# C:\Users\gcwhi\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    Unnamed: 0 Accident_Index 1st_Road_Class Accident_Severity  \
# 0           0  200501BS00004              A            Slight
# 1           1  200501BS00006   Unclassified            Slight
# 2           2  200501BS00006   Unclassified            Slight
# 3           3  200501BS00007              C            Slight
# 4           4  200501BS00009              A            Slight
#
#   Carriageway_Hazards  Year        Date Day_of_Week  \
# 0                None  2005  2005-01-07      Friday
# 1                None  2005  2005-01-11     Tuesday
# 2                None  2005  2005-01-11     Tuesday
# 3                None  2005  2005-01-13    Thursday
# 4                None  2005  2005-01-14      Friday
#
# ...

# %%
# select the columns chasen by the project team
columns = ['Accident_Index', '1st_Road_Class','Accident_Severity','Year','Date','Day_of_Week','Latitude','Light_Conditions','Local_Authority_(District)','Longitude','Number_of_Casualties','Number_of_Vehicles','Road_Surface_Conditions','Road_Type','Special_Conditions_at_Site','Speed_limit','Time','Urban_or_Rural_Area','Weather_Conditions','Age_Band_of_Driver','Age_of_Vehicle','Engine_Capacity_.CC.','Journey_Purpose_of_Driver','Junction_Location','make','model','Propulsion_Code','Sex_of_Driver','Towing_and_Articulation','Vehicle_Manoeuvre','Vehicle_Type','Was_Vehicle_Left_Hand_Drive']
           
final_df1 = pd.DataFrame(final_df, columns=columns)
final_df1
# Out:
#         Accident_Index 1st_Road_Class Accident_Severity  Year        Date  \
# 0        200501BS00004              A            Slight  2005  2005-01-07
# 1        200501BS00006   Unclassified            Slight  2005  2005-01-11
# 2        200501BS00006   Unclassified            Slight  2005  2005-01-11
# 3        200501BS00007              C            Slight  2005  2005-01-13
# 4        200501BS00009              A            Slight  2005  2005-01-14
# ...                ...            ...               ...   ...         ...
# 1556235  2016984130916              B            Slight  2016  2016-10-28
# 1556236  2016984130916              B            Slight  2016  2016-10-28
# 1556237  2016984131116              B            Slight  2016  2016-11-01
# 1556238  2016984131316              B            Slight  2016  2016-10-29
# 1556239  2016984133416           A(M)            Slight  2016  2016-12-25
#
#         Day_of_Week   Latitude       Light_Conditions  \
# ...

# %%
# create and save a csv for each year
df_2010 = final_df1.loc[final_df1["Year"]==2010]
df_2010.to_csv("Resources/2010.csv")
df_2010.head()
# Out:
#        Accident_Index 1st_Road_Class Accident_Severity  Year        Date  \
# 478587  201001BS70003              B            Slight  2010  2010-01-11
# 478588  201001BS70004              A            Slight  2010  2010-01-11
# 478589  201001BS70007   Unclassified            Slight  2010  2010-01-02
# 478590  201001BS70007   Unclassified            Slight  2010  2010-01-02
# 478591  201001BS70008              A            Slight  2010  2010-01-04
#
#        Day_of_Week   Latitude       Light_Conditions  \
# 478587      Monday  51.484087               Daylight
# 478588      Monday  51.509212  Darkness - lights lit
# 478589    Saturday  51.513314  Darkness - lights lit
# 478590    Saturday  51.513314  Darkness - lights lit
# 478591      Monday  51.484361  Darkness - lights lit
#
#        Local_Authority_(District)  Longitude  ...  Journey_Purpose_of_Driver  \
# 478587     Kensington and Chelsea  -0.164002  ...     Commuting to/from work
# ...

# %%
# create and save a csv for each year
df_2011 = final_df1.loc[final_df1["Year"]==2011]
df_2011.to_csv("Resources/2011.csv")
df_2011.head()
# Out:
#        Accident_Index 1st_Road_Class Accident_Severity  Year        Date  \
# 624421  201101BS70002              C           Serious  2011  2011-01-11
# 624422  201101BS70005   Unclassified            Slight  2011  2011-01-25
# 624423  201101BS70005   Unclassified            Slight  2011  2011-01-25
# 624424  201101BS70007              A            Slight  2011  2011-01-06
# 624425  201101BS70009              C            Slight  2011  2011-01-27
#
#        Day_of_Week   Latitude       Light_Conditions  \
# 624421     Tuesday  51.495710  Darkness - lights lit
# 624422     Tuesday  51.497875  Darkness - lights lit
# 624423     Tuesday  51.497875  Darkness - lights lit
# 624424    Thursday  51.482671  Darkness - lights lit
# 624425    Thursday  51.486008               Daylight
#
#        Local_Authority_(District)  Longitude  ...  Journey_Purpose_of_Driver  \
# 624421     Kensington and Chelsea  -0.165408  ...                  Not known
# ...

# %%
# create and save a csv for each year
df_2012 = final_df1.loc[final_df1["Year"]==2012]
df_2012.to_csv("Resources/2012.csv")
df_2012.head()
# Out:
#        Accident_Index 1st_Road_Class Accident_Severity  Year        Date  \
# 771813  201201BS70001              A            Slight  2012  2012-01-19
# 771814  201201BS70003              A            Slight  2012  2012-01-10
# 771815  201201BS70003              A            Slight  2012  2012-01-10
# 771816  201201BS70004              C            Slight  2012  2012-01-18
# 771817  201201BS70005              B            Slight  2012  2012-01-17
#
#        Day_of_Week   Latitude       Light_Conditions  \
# 771813    Thursday  51.493429  Darkness - lights lit
# 771814     Tuesday  51.487618               Daylight
# 771815     Tuesday  51.487618               Daylight
# 771816   Wednesday  51.514325               Daylight
# 771817     Tuesday  51.497614  Darkness - lights lit
#
#        Local_Authority_(District)  Longitude  ...  Journey_Purpose_of_Driver  \
# 771813     Kensington and Chelsea  -0.169101  ...                  Not known
# ...

# %%
# create and save a csv for each year
df_2013 = final_df1.loc[final_df1["Year"]==2013]
df_2013.to_csv("Resources/2013.csv")
df_2013.head()
# Out:
#        Accident_Index 1st_Road_Class Accident_Severity  Year        Date  \
# 914355  201301BS70003              A           Serious  2013  2013-01-02
# 914356  201301BS70005              A            Slight  2013  2013-01-04
# 914357  201301BS70007              B            Slight  2013  2013-01-10
# 914358  201301BS70007              B            Slight  2013  2013-01-10
# 914359  201301BS70009              A            Slight  2013  2013-01-04
#
#        Day_of_Week   Latitude       Light_Conditions  \
# 914355   Wednesday  51.486361               Daylight
# 914356      Friday  51.495115               Daylight
# 914357    Thursday  51.516808               Daylight
# 914358    Thursday  51.516808               Daylight
# 914359      Friday  51.492922  Darkness - lights lit
#
#        Local_Authority_(District)  Longitude  ...  Journey_Purpose_of_Driver  \
# 914355     Kensington and Chelsea  -0.171402  ...    Journey as part of work
# ...

# %%
# create and save a csv for each year
df_2014 = final_df1.loc[final_df1["Year"]==2014]
df_2014.to_csv("Resources/2014.csv")
df_2014.head()
# Out:
#         Accident_Index 1st_Road_Class Accident_Severity  Year        Date  \
# 1056142  201401BS70001              A            Slight  2014  2014-01-09
# 1056143  201401BS70002              A            Slight  2014  2014-01-20
# 1056144  201401BS70003              A            Slight  2014  2014-01-21
# 1056145  201401BS70003              A            Slight  2014  2014-01-21
# 1056146  201401BS70004              C            Slight  2014  2014-01-15
#
#         Day_of_Week   Latitude             Light_Conditions  \
# 1056142    Thursday  51.496345                     Daylight
# 1056143      Monday  51.489523  Darkness - lighting unknown
# 1056144     Tuesday  51.490536                     Daylight
# 1056145     Tuesday  51.490536                     Daylight
# 1056146   Wednesday  51.496668        Darkness - lights lit
#
#         Local_Authority_(District)  Longitude  ...  Journey_Purpose_of_Driver  \
# ...

# %%
# create and save a csv for each year
df_2015 = final_df1.loc[final_df1["Year"]==2015]
df_2015.to_csv("Resources/2015.csv")
df_2015.head()
# Out:
#         Accident_Index 1st_Road_Class Accident_Severity  Year        Date  \
# 1207324  201501BS70001              C            Slight  2015  2015-01-12
# 1207325  201501BS70002   Unclassified            Slight  2015  2015-01-12
# 1207326  201501BS70004              B            Slight  2015  2015-01-12
# 1207327  201501BS70009              A            Slight  2015  2015-01-15
# 1207328  201501BS70009              A            Slight  2015  2015-01-15
#
#         Day_of_Week   Latitude       Light_Conditions  \
# 1207324      Monday  51.505538  Darkness - lights lit
# 1207325      Monday  51.491836               Daylight
# 1207326      Monday  51.514910  Darkness - lights lit
# 1207327    Thursday  51.500788               Daylight
# 1207328    Thursday  51.500788               Daylight
#
#         Local_Authority_(District)  Longitude  ...  Journey_Purpose_of_Driver  \
# 1207324     Kensington and Chelsea  -0.198465  ...    Journey as part of work
# ...

# %%
# create and save a csv for each year
df_2016 = final_df1.loc[final_df1["Year"]==2016]
df_2016.to_csv("Resources/2016.csv")
df_2016.head()
# Out:
#         Accident_Index 1st_Road_Class Accident_Severity  Year        Date  \
# 1372440  2016010000005              A            Slight  2016  2016-11-01
# 1372441  2016010000006              A            Slight  2016  2016-11-01
# 1372442  2016010000008              A            Slight  2016  2016-11-01
# 1372443  2016010000016              A            Slight  2016  2016-11-01
# 1372444  2016010000018              A            Slight  2016  2016-11-01
#
#         Day_of_Week   Latitude         Light_Conditions  \
# 1372440     Tuesday  51.584754  Darkness - lights unlit
# 1372441     Tuesday  51.449595    Darkness - lights lit
# 1372442     Tuesday  51.543563    Darkness - lights lit
# 1372443     Tuesday  51.404958                 Daylight
# 1372444     Tuesday  51.483139                 Daylight
#
#         Local_Authority_(District)  Longitude  ...  Journey_Purpose_of_Driver  \
# 1372440                      Brent  -0.279323  ...                  Not known
# ...

# %%
# create and save a csv for 2010 to 2016 to the resourses folder to be used by all of the project team
df_all = final_df1.loc[final_df1["Year"]>=2010]
df_all.to_csv("Resources/all.csv")
df_all.head()
# Out:
#        Accident_Index 1st_Road_Class Accident_Severity  Year        Date  \
# 478587  201001BS70003              B            Slight  2010  2010-01-11
# 478588  201001BS70004              A            Slight  2010  2010-01-11
# 478589  201001BS70007   Unclassified            Slight  2010  2010-01-02
# 478590  201001BS70007   Unclassified            Slight  2010  2010-01-02
# 478591  201001BS70008              A            Slight  2010  2010-01-04
#
#        Day_of_Week   Latitude       Light_Conditions  \
# 478587      Monday  51.484087               Daylight
# 478588      Monday  51.509212  Darkness - lights lit
# 478589    Saturday  51.513314  Darkness - lights lit
# 478590    Saturday  51.513314  Darkness - lights lit
# 478591      Monday  51.484361  Darkness - lights lit
#
#        Local_Authority_(District)  Longitude  ...  Journey_Purpose_of_Driver  \
# 478587     Kensington and Chelsea  -0.164002  ...     Commuting to/from work
# ...

# %%
# review data types 
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1077653 entries, 478587 to 1556239
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   Accident_Index               1077653 non-null  object
#  1   1st_Road_Class               1077653 non-null  object
#  2   Accident_Severity            1077653 non-null  object
#  3   Year                         1077653 non-null  int64
#  4   Date                         1077653 non-null  object
#  5   Day_of_Week                  1077653 non-null  object
#  6   Latitude                     1077653 non-null  float64
#  7   Light_Conditions             1077653 non-null  object
#  8   Local_Authority_(District)   1077653 non-null  object
#  9   Longitude                    1077653 non-null  float64
#  10  Number_of_Casualties         1077653 non-null  int64
#  11  Number_of_Vehicles           1077653 non-null  int64
# ...

# %%
# Count how many accidents have occured within each year
acc_counts = df_all["Year"].value_counts()
acc_counts.head(10)
# Out:
# 2016    183800
# 2015    165116
# 2014    151182
# 2011    147392
# 2010    145834
# 2012    142542
# 2013    141787
# Name: Year, dtype: int64
