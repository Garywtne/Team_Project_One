# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd
import scipy.stats as sts
from scipy.stats import linregress
import numpy as np
import seaborn as sns
import scipy.stats as st

# %%
accident_df = pd.read_csv("all.csv", low_memory=False)

accident_df.head()
# Out:
#    Unnamed: 0 Accident_Index 1st_Road_Class Accident_Severity  Year  \
# 0      478587  201001BS70003              B            Slight  2010
# 1      478588  201001BS70004              A            Slight  2010
# 2      478589  201001BS70007   Unclassified            Slight  2010
# 3      478590  201001BS70007   Unclassified            Slight  2010
# 4      478591  201001BS70008              A            Slight  2010
#
#          Date Day_of_Week   Latitude       Light_Conditions  \
# 0  2010-01-11      Monday  51.484087               Daylight
# 1  2010-01-11      Monday  51.509212  Darkness - lights lit
# 2  2010-01-02    Saturday  51.513314  Darkness - lights lit
# 3  2010-01-02    Saturday  51.513314  Darkness - lights lit
# 4  2010-01-04      Monday  51.484361  Darkness - lights lit
#
#   Local_Authority_(District)  ...  Journey_Purpose_of_Driver  \
# 0     Kensington and Chelsea  ...     Commuting to/from work
# 1     Kensington and Chelsea  ...    Journey as part of work
# ...

# %%
all_average = accident_df.groupby(["Speed_limit"]).mean()
all_average.sort_values(by=["Number_of_Casualties"], ascending=False)
average_casualties = all_average["Number_of_Casualties"]
len(average_casualties)
# Out:
# 8

# %%
all_average.
# Out:
#                Unnamed: 0         Year   Latitude  Longitude  \
# Speed_limit
# 10           1.232133e+06  2015.000000  51.616118  -0.133423
# 15           6.230945e+05  2010.000000  55.785185  -4.011792
# 20           1.178446e+06  2014.227345  52.507229  -1.435005
# 30           1.005954e+06  2013.123729  52.486797  -1.306082
# 40           1.026175e+06  2013.163722  52.433875  -1.320840
# 50           1.047666e+06  2013.295424  52.441736  -1.341802
# 60           1.021696e+06  2013.045297  52.831584  -1.635675
# 70           1.029928e+06  2013.141575  52.466215  -1.286745
#
#              Number_of_Casualties  Number_of_Vehicles  Age_of_Vehicle  \
# Speed_limit
# 10                       1.000000            1.000000       10.000000
# 15                       1.000000            2.000000        9.500000
# 20                       1.247302            1.932646        7.689326
# 30                       1.359357            2.051464        7.559474
# ...

# %%
corr=round(st.pearsonr(all_average[""],average_casualties)[0],2)
print(f"The correlation is {corr}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13052/1743212874.py in <module>
# ----> 1 corr=round(st.pearsonr(accident_df['Speed_limit'],average_casualties)[0],2)
#       2 print(f"The correlation is {corr}")
#
# ~\anaconda3\envs\DataCoursePython\lib\site-packages\scipy\stats\stats.py in pearsonr(x, y)
#    4011     n = len(x)
#    4012     if n != len(y):
# -> 4013         raise ValueError('x and y must have the same length.')
#    4014
#    4015     if n < 2:
#
# ValueError: x and y must have the same length.

# %%
accident_df["Number_of_Casualties"].max()
# Out:
# 93
